# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import SAFutils
import glob

# %matplotlib inline
pd.options.display.max_columns = 137

# %% [markdown]
# ## Aggregate Police Force Across Years

# %% [markdown]
# I should get more information to see if the kinds of force are changing

# %%
aggregates = {"pf_race":{}, "pf_hour": {}, "pf_day": {}}

for file in glob.glob('2*.csv'):
    year, df = SAFutils.SAF_data_cleaner(file)
    print(year)
    df["used_force"] = np.where((df["pf_hands"] == "Y") | (df["pf_wall"] == "Y") | (df["pf_grnd"] == "Y") |
                            (df["pf_drwep"] == "Y") | (df["pf_ptwep"] == "Y") | (df["pf_baton"] == "Y") | 
                            (df["pf_hcuff"] == "Y") | (df["pf_pepsp"] == "Y") | (df["pf_other"] == "Y"), 1, 0)
    
    aggregates["pf_race"][year] = df.groupby(["race"]).mean()['used_force']
    aggregates["pf_hour"][year] = df.groupby(["hour"]).mean()['used_force'],
    aggregates["pf_day"][year] = df.groupby(["dayofyear"]).mean()['used_force']
# Out:
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015

# %%
plt.figure(figsize=(10,5))
years = [x for x in range(2003, 2016)]
yr_avgs = np.zeros(24)
for year in years:
    data = aggregates["pf_hour"][year][0]
    yr_avgs = [sum(x) for x in zip(data.values, yr_avgs)]
    plt.plot(data.index, data.values, color='b', alpha=0.2)
    
yr_avgs = [x/len(years) for x in yr_avgs]
plt.plot(yr_avgs, color='r')
plt.xlim([-2,25])
plt.xlabel("Hour of Day")
plt.ylabel("Precent of Stop Using Force")
plt.title("Hourly Use of Force")
plt.show()

# %%
import pickle
holder = pickle.load(open("aggregated.p", "rb"))

# %%
full_day_series = []
for year, data in sorted(holder["dayofyear"].items()):
    full_day_series += list(data)
    
full_pf_series = []
for year, data in sorted(aggregates["pf_day"].items()):
    full_pf_series += list(data)

# %%
# Aggregating at the weekly level

wk_agg_pf = []
for i, val in enumerate(full_pf_series):
    if i % 6 == 0:
        wk_agg_pf.append(val)
    else:
        wk_agg_pf[-1] += val

wk_agg_cnts = []
for i, val in enumerate(full_day_series):
    if i % 6 == 0:
        wk_agg_cnts.append(val)
    else:
        wk_agg_cnts[-1] += val
        
wk_agg_pf = [x/7 for x in wk_agg_pf]
wk_agg_cnts = [x/7 for x in wk_agg_cnts]

# %%
years = [str(x) for x in range(2003, 2016)]

fig, host = plt.subplots()
fig.set_figheight(8)
fig.set_figwidth(15)
host.plot(wk_agg_cnts, alpha=0.6)
host.set_ylabel("Number of Stops")
host.set_ylim([-200, 4000])


par1 = host.twinx()
par1.plot(wk_agg_pf, "g", alpha=0.55, axes=par1)
par1.set_ylim([0, .5])
par1.set_ylabel("% Involving Police Force")
par1.grid(b=False)


plt.title("Stops Aggregated by Year between Q1 2003 and Q2 2015\n")
fig.show()
# Out:
# /usr/local/lib/python3.4/dist-packages/matplotlib/figure.py:387: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
plt.figure(figsize=(20, 4))
plt.plot(wk_agg_pf, color='g', alpha=0.8)
plt.show()

plt.figure(figsize=(20,4))
plt.plot(wk_agg_cnts)
plt.show()

# %% [markdown]
# ## Racial Disparities in Police Force

# %%
years = [x for x in range(2003, 2016)]
pf_race = {}
for year in years:
    pf_race[year] = aggregates["pf_race"][year]
pf_race_df = pd.DataFrame(pf_race)

# %%
pf_race_df.plot(kind='bar', figsize=(30,5))
plt.ylabel("% Involving Police Force")
plt.xlabel("Race")
plt.show()

# %% [markdown]
# ### Modeling Likelyhood
# Want to develop a model for how different features impact use of force

# %% [raw]
# Variables

# %%
import statsmodels as sm

# %% [markdown]
# Should be collecting variance in order to determine error bars?
#     Feel like it is probably best practice

# %%
df.columns.values
# Out:
# array(['year', 'pct', 'ser_num', 'datestop', 'timestop', 'recstat',
#        'inout', 'trhsloc', 'perobs', 'crimsusp', 'perstop', 'typeofid',
#        'explnstp', 'othpers', 'arstmade', 'arstoffn', 'sumissue',
#        'sumoffen', 'compyear', 'comppct', 'offunif', 'officrid', 'frisked',
#        'searched', 'contrabn', 'adtlrept', 'pistol', 'riflshot',
#        'asltweap', 'knifcuti', 'machgun', 'othrweap', 'pf_hands',
#        'pf_wall', 'pf_grnd', 'pf_drwep', 'pf_ptwep', 'pf_baton',
#        'pf_hcuff', 'pf_pepsp', 'pf_other', 'radio', 'ac_rept', 'ac_inves',
#        'rf_vcrim', 'rf_othsw', 'ac_proxm', 'rf_attir', 'cs_objcs',
#        'cs_descr', 'cs_casng', 'cs_lkout', 'rf_vcact', 'cs_cloth',
#        'cs_drgtr', 'ac_evasv', 'ac_assoc', 'cs_furtv', 'rf_rfcmp',
#        'ac_cgdir', 'rf_verbl', 'cs_vcrim', 'cs_bulge', 'cs_other',
#        'ac_incid', 'ac_time', 'rf_knowl', 'ac_stsnd', 'ac_other',
#        'sb_hdobj', 'sb_outln', 'sb_admis', 'sb_other', 'repcmd', 'revcmd',
#        'rf_furt', 'rf_bulg', 'offverb', 'offshld', 'sex', 'race', 'dob',
#        'age', 'ht_feet', 'ht_inch', 'weight', 'haircolr', 'eyecolor',
#        'build', 'othfeatr', 'addrtyp', 'rescode', 'premtype', 'premname',
#        'addrnum', 'stname', 'stinter', 'crossst', 'aptnum', 'city',
#        'state', 'zip', 'addrpct', 'sector', 'beat', 'post', 'xcoord',
#        'ycoord', 'dettypcm', 'linecm', 'detailcm', 'hour', 'minute',
#        'dayofyear', 'month', 'dayofweek', 'weekofyear', 'day'], dtype=object)

# %% [markdown]
# Investigate

# %%
df["arstmade"] = np.where(df["arstmade"] == "Y", 1, 0)

# %%
plt.figure(figsize=(20, 5))
df.groupby(["dayofyear"]).mean()["arstmade"].plot()

# %%
df.groupby(["race"]).var()["arstmade"]
# Out:
# race
#      0.030097
# A    0.067672
# B    0.070993
# I    0.067076
# P    0.081295
# Q    0.075740
# U    0.000000
# W    0.077499
# X    0.062089
# Z    0.053750
# Name: arstmade, dtype: float64

# %%
df.groupby(["arstmade"]).var()["used_force"]
# Out:
# arstmade
# N    0.211756
# Y    0.236725
# Name: used_force, dtype: float64

# %%
df.groupby(["arstmade"]).mean()["used_force"]
# Out:
# arstmade
# N    0.304436
# Y    0.615298
# Name: used_force, dtype: float64

# %%
year, df = SAFutils.SAF_data_cleaner("2003.csv")
print(year)

df["used_force"] = np.where((df["pf_hands"] == "Y") | (df["pf_wall"] == "Y") | (df["pf_grnd"] == "Y") |
                        (df["pf_drwep"] == "Y") | (df["pf_ptwep"] == "Y") | (df["pf_baton"] == "Y") | 
                        (df["pf_hcuff"] == "Y") | (df["pf_pepsp"] == "Y") | (df["pf_other"] == "Y"), 1, 0)
# Out:
# 2003

# %%
df.groupby(["hour"]).mean()["used_force"]
# Out:
# hour
# 0     0.283506
# 1     0.294711
# 2     0.293060
# 3     0.300885
# 4     0.355004
# 5     0.345010
# 6     0.328962
# 7     0.319026
# 8     0.241629
# 9     0.207151
# 10    0.231440
# 11    0.268432
# 12    0.273679
# 13    0.274583
# 14    0.281371
# 15    0.305565
# 16    0.314795
# 17    0.330225
# 18    0.314637
# 19    0.317725
# 20    0.516663
# 21    0.332755
# 22    0.342397
# 23    0.344722
# Name: used_force, dtype: float64

# %%
hourly_counts = df.groupby(["hour"]).mean()["used_force"]

# %% [markdown]
# Probably a good opportunity for a stacked barchart

# %%
hours = hourly_counts.index
counts = hourly_counts.values
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-8169b214cd6e> in <module>()
# ----> 1 hours = hourly_counts.index
#       2 counts = hourly_counts.values
#
# NameError: name 'hourly_counts' is not defined

# %%
plt.plot(hours, counts)
plt.title("Portion of Stops Using Force")
plt.xlabel("Hour of the Day")
plt.ylabel("Count")
plt.xlim([0,24])
plt.xticks([0,4,8,12,16,20,24])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-f003f8f68573> in <module>()
# ----> 1 plt.plot(hours, counts)
#       2 plt.title("Portion of Stops Using Force")
#       3 plt.xlabel("Hour of the Day")
#       4 plt.ylabel("Count")
#       5 plt.xlim([0,24])
#
# NameError: name 'hours' is not defined

# %% [markdown]
# ## Use of Force Data
#
# Columns have prefix pf_

# %%
pf_df = df.filter(regex="pf_.*")

# %%
pf_df.head()
# Out:
#   pf_hands pf_wall pf_grnd pf_drwep pf_ptwep pf_baton pf_hcuff pf_pepsp  \
# 0        N       N       N        N        N        N        N        N
# 1        N       N       N        N        N        N        N        N
# 2        N       N       N        N        N        N        N        N
# 3        N       N       N        N        N        N        N        N
# 4        Y       Y       N        N        N        N        Y        N
#
#   pf_other
# 0        N
# 1        N
# 2        N
# 3        N
# 4        N

# %%
for col_name in pf_df:
    print(col_name)
    print(pf_df[col_name].value_counts())
    print()
# Out:
# pf_hands
# N    129674
# Y     31177
# dtype: int64
#
# pf_wall
# N    150334
# Y     10517
# dtype: int64
#
# pf_grnd
# N    159222
# Y      1629
# dtype: int64
#
# pf_drwep
# N    159425
# Y      1426
# dtype: int64
#
# pf_ptwep
# N    159038
# Y      1813
# dtype: int64
#
# pf_baton
# N    160792
# Y        59
# dtype: int64
#
# pf_hcuff
# N    151755
# Y      9096
# dtype: int64
#
# pf_pepsp
# N    160779
# Y        72
# dtype: int64
#
# pf_other
# N    148869
# Y     11982
# dtype: int64

# %%
df["used_force"] = np.where((df["pf_hands"] == "Y") | (df["pf_wall"] == "Y") | (df["pf_grnd"] == "Y") |
                            (df["pf_drwep"] == "Y") | (df["pf_ptwep"] == "Y") | (df["pf_baton"] == "Y") | 
                            (df["pf_hcuff"] == "Y") | (df["pf_pepsp"] == "Y") | (df["pf_other"] == "Y"), "Y", "N")

# %%
df.loc[:, ["pf_hands", "pf_wall", "pf_grnd", "pf_drwep", "pf_ptwep", 
           "pf_baton", "pf_hcuff", "pf_pepsp", "pf_other", "used_force"]].head(10)
# Out:
#   pf_hands pf_wall pf_grnd pf_drwep pf_ptwep pf_baton pf_hcuff pf_pepsp  \
# 0        N       N       N        N        N        N        N        N
# 1        N       N       N        N        N        N        N        N
# 2        N       N       N        N        N        N        N        N
# 3        N       N       N        N        N        N        N        N
# 4        Y       Y       N        N        N        N        Y        N
# 5        N       N       N        N        N        N        N        N
# 6        N       N       N        N        N        N        N        N
# 7        N       N       N        N        N        N        N        N
# 8        N       N       N        N        N        N        N        N
# 9        Y       N       N        N        N        N        N        N
#
#   pf_other used_force
# 0        N          N
# 1        N          N
# 2        N          N
# 3        N          N
# 4        N          Y
# 5        N          N
# 6        N          N
# 7        N          N
# 8        N          N
# 9        N          Y
